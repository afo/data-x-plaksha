# %% [markdown]
# <img src="http://i67.tinypic.com/2jcbwcw.png" align="left"></img><br><br><br><br>
#
#
# ## SOLUTIONS Breakout: Web scraping & web crawling
#
# **Author List**: Alexander Fred Ojala
#
# **Original Sources**: https://www.crummy.com/software/BeautifulSoup/bs4/doc/ & https://www.dataquest.io/blog/web-scraping-tutorial-python/
#
# **License**: Feel free to do whatever you want to with this code
#
# **Compatibility:** Python 2.x and 3.x

# %% [markdown]
# ---
# <a id='sec4'></a>
# # Breakout problem
#
#
# In this week's breakout you should extract live weather data in Berkeley from:
#
# [http://forecast.weather.gov/MapClick.php?lat=37.87158815800046&lon=-122.27274583799971](http://forecast.weather.gov/MapClick.php?lat=37.87158815800046&lon=-122.27274583799971)
#
# * Task scrape
#     * period / day (as Tonight, Friday, FridayNight etc.
#     * the temperature for the period (as Low, High)
#     * the long weather description (e.g. Partly cloudy, with a low around 49..)
#
# Store the scraped data strings in a Pandas DataFrame
#
#
#
# **Hint:** The weather information is found in a div tag with `id='seven-day-forecast'`

# %% [markdown]
# # Breakout solution

# %%
import requests
import bs4 as bs
import pandas as pd

source = requests.get('http://forecast.weather.gov/MapClick.php?lat=37.87158815800046&lon=-122.27274583799971').content
soup = bs.BeautifulSoup(source,features='lxml')

# %%
forecast = soup.find(id='seven-day-forecast')

# %%
print(forecast.prettify())
# Out:
# <div class="panel panel-default" id="seven-day-forecast">
#  <div class="panel-heading">
#   <b>
#    Extended Forecast for
#   </b>
#   <h2 class="panel-title">
#    Berkeley CA
#   </h2>
#  </div>
#  <div class="panel-body" id="seven-day-forecast-body">
#   <div id="seven-day-forecast-container">
#    <ul class="list-unstyled" id="seven-day-forecast-list">
#     <li class="forecast-tombstone">
#      <div class="tombstone-container">
#       <p class="period-name">
#        Tonight
#        <br/>
#        <br/>
#       </p>
#       <p>
#        <img alt="Tonight: Clear, with a low around 60. Breezy, with an east northeast wind 8 to 13 mph increasing to 19 to 24 mph after midnight. " class="forecast-icon" src="DualImage.php?i=nskc&amp;j=nwind_skc" title="Tonight: Clear, with a low around 60. Breezy, with an east northeast wind 8 to 13 mph increasing to 19 to 24 mph after midnight. "/>
#       </p>
#       <p class="short-desc">
#        Clear then
#        <br/>
#        Clear and
#        <br/>
#        Breezy
#       </p>
#       <p class="temp temp-low">
#        Low: 60 °F
#       </p>
#      </div>
#     </li>
#     <li class="forecast-tombstone">
#      <div class="tombstone-container">
#       <p class="period-name">
#        Tuesday
#        <br/>
#        <br/>
#       </p>
#       <p>
#        <img alt="Tuesday: Sunny, with a high near 87. Breezy, with an east northeast wind 16 to 25 mph, with gusts as high as 31 mph. " class="forecast-icon" src="newimages/medium/wind_skc.png" title="Tuesday: Sunny, with a high near 87. Breezy, with an east northeast wind 16 to 25 mph, with gusts as high as 31 mph. "/>
#       </p>
#       <p class="short-desc">
#        Sunny and
#        <br/>
#        Breezy
#       </p>
#       <p class="temp temp-high">
#        High: 87 °F
#       </p>
#      </div>
#     </li>
#     <li class="forecast-tombstone">
#      <div class="tombstone-container">
#       <p class="period-name">
#        Tuesday
#        <br/>
#        Night
#       </p>
#       <p>
#        <img alt="Tuesday Night: Clear, with a low around 59. Northeast wind 5 to 9 mph becoming light east northeast  after midnight. " class="forecast-icon" src="newimages/medium/nskc.png" title="Tuesday Night: Clear, with a low around 59. Northeast wind 5 to 9 mph becoming light east northeast  after midnight. "/>
#       </p>
#       <p class="short-desc">
#        Clear
#       </p>
#       <p class="temp temp-low">
#        Low: 59 °F
#       </p>
#      </div>
#     </li>
#     <li class="forecast-tombstone">
#      <div class="tombstone-container">
#       <p class="period-name">
#        Wednesday
#        <br/>
#        <br/>
#       </p>
#       <p>
#        <img alt="Wednesday: Sunny, with a high near 81. East northeast wind around 10 mph. " class="forecast-icon" src="newimages/medium/skc.png" title="Wednesday: Sunny, with a high near 81. East northeast wind around 10 mph. "/>
#       </p>
#       <p class="short-desc">
#        Sunny
#       </p>
#       <p class="temp temp-high">
#        High: 81 °F
#       </p>
#      </div>
#     </li>
#     <li class="forecast-tombstone">
#      <div class="tombstone-container">
#       <p class="period-name">
#        Wednesday
#        <br/>
#        Night
#       </p>
#       <p>
#        <img alt="Wednesday Night: Clear, with a low around 56. North wind 3 to 6 mph. " class="forecast-icon" src="newimages/medium/nskc.png" title="Wednesday Night: Clear, with a low around 56. North wind 3 to 6 mph. "/>
#       </p>
#       <p class="short-desc">
#        Clear
#       </p>
#       <p class="temp temp-low">
#        Low: 56 °F
#       </p>
#      </div>
#     </li>
#     <li class="forecast-tombstone">
#      <div class="tombstone-container">
#       <p class="period-name">
#        Thursday
#        <br/>
#        <br/>
#       </p>
#       <p>
#        <img alt="Thursday: Sunny, with a high near 80." class="forecast-icon" src="newimages/medium/skc.png" title="Thursday: Sunny, with a high near 80."/>
#       </p>
#       <p class="short-desc">
#        Sunny
#       </p>
#       <p class="temp temp-high">
#        High: 80 °F
#       </p>
#      </div>
#     </li>
#     <li class="forecast-tombstone">
#      <div class="tombstone-container">
#       <p class="period-name">
#        Thursday
#        <br/>
#        Night
#       </p>
#       <p>
#        <img alt="Thursday Night: Clear, with a low around 55." class="forecast-icon" src="newimages/medium/nskc.png" title="Thursday Night: Clear, with a low around 55."/>
#       </p>
#       <p class="short-desc">
#        Clear
#       </p>
#       <p class="temp temp-low">
#        Low: 55 °F
#       </p>
#      </div>
#     </li>
#     <li class="forecast-tombstone">
#      <div class="tombstone-container">
#       <p class="period-name">
#        Friday
#        <br/>
#        <br/>
#       </p>
#       <p>
#        <img alt="Friday: Sunny, with a high near 75." class="forecast-icon" src="newimages/medium/few.png" title="Friday: Sunny, with a high near 75."/>
#       </p>
#       <p class="short-desc">
#        Sunny
#       </p>
#       <p class="temp temp-high">
#        High: 75 °F
#       </p>
#      </div>
#     </li>
#     <li class="forecast-tombstone">
#      <div class="tombstone-container">
#       <p class="period-name">
#        Friday
#        <br/>
#        Night
#       </p>
#       <p>
#        <img alt="Friday Night: Clear, with a low around 53." class="forecast-icon" src="newimages/medium/nskc.png" title="Friday Night: Clear, with a low around 53."/>
#       </p>
#       <p class="short-desc">
#        Clear
#       </p>
#       <p class="temp temp-low">
#        Low: 53 °F
#       </p>
#      </div>
#     </li>
#    </ul>
#   </div>
#   <script type="text/javascript">
#    // equalize forecast heights
# $(function () {
# 	var maxh = 0;
# 	$(".forecast-tombstone .short-desc").each(function () {
# 		var h = $(this).height();
# 		if (h > maxh) { maxh = h; }
# 	});
# 	$(".forecast-tombstone .short-desc").height(maxh);
# });
#   </script>
#  </div>
# </div>

# %%
day = [d.text for d in forecast.find_all(class_='period-name')]
temp = [temp.text for temp in forecast.find_all(class_='temp')]
desc = forecast.find_all('img')

# %%
print(day)
print()
print(temp)
# Out:
# ['Tonight', 'Tuesday', 'TuesdayNight', 'Wednesday', 'WednesdayNight', 'Thursday', 'ThursdayNight', 'Friday', 'FridayNight']
#
# ['Low: 60 °F', 'High: 87 °F', 'Low: 59 °F', 'High: 81 °F', 'Low: 56 °F', 'High: 80 °F', 'Low: 55 °F', 'High: 75 °F', 'Low: 53 °F']

# %%
# extract weather description
desc_list=list()
for txt in desc:
    print(txt.get('alt'))
    desc_list.append(txt.get('alt'))
# Out:
# Tonight: Clear, with a low around 60. Breezy, with an east northeast wind 8 to 13 mph increasing to 19 to 24 mph after midnight.
# Tuesday: Sunny, with a high near 87. Breezy, with an east northeast wind 16 to 25 mph, with gusts as high as 31 mph.
# Tuesday Night: Clear, with a low around 59. Northeast wind 5 to 9 mph becoming light east northeast  after midnight.
# Wednesday: Sunny, with a high near 81. East northeast wind around 10 mph.
# Wednesday Night: Clear, with a low around 56. North wind 3 to 6 mph.
# Thursday: Sunny, with a high near 80.
# Thursday Night: Clear, with a low around 55.
# Friday: Sunny, with a high near 75.
# Friday Night: Clear, with a low around 53.

# %%
pd.set_option('display.max_colwidth', -1) # to print full results
df = pd.DataFrame({'day':day,'temp':temp,'desc':desc_list})
print('Berkeley 7 day weather forecast')
df
# Out:
# Berkeley 7 day weather forecast
#               day  \
# 0  Tonight
# 1  Tuesday
# 2  TuesdayNight
# 3  Wednesday
# 4  WednesdayNight
# 5  Thursday
# 6  ThursdayNight
# 7  Friday
# 8  FridayNight
#
#                                                                                                                                 desc  \
# 0  Tonight: Clear, with a low around 60. Breezy, with an east northeast wind 8 to 13 mph increasing to 19 to 24 mph after midnight.
# 1  Tuesday: Sunny, with a high near 87. Breezy, with an east northeast wind 16 to 25 mph, with gusts as high as 31 mph.
# 2  Tuesday Night: Clear, with a low around 59. Northeast wind 5 to 9 mph becoming light east northeast  after midnight.
# 3  Wednesday: Sunny, with a high near 81. East northeast wind around 10 mph.
# 4  Wednesday Night: Clear, with a low around 56. North wind 3 to 6 mph.
# 5  Thursday: Sunny, with a high near 80.
# 6  Thursday Night: Clear, with a low around 55.
# 7  Friday: Sunny, with a high near 75.
# 8  Friday Night: Clear, with a low around 53.
#
#           temp
# 0  Low: 60 °F
# 1  High: 87 °F
# 2  Low: 59 °F
# 3  High: 81 °F
# 4  Low: 56 °F
# 5  High: 80 °F
# 6  Low: 55 °F
# 7  High: 75 °F
# 8  Low: 53 °F

# %%
pd.options.display.max_colwidth=50 #change back to default max col_width
