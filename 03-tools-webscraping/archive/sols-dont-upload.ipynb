# %% [markdown]
# <img src="https://raw.githubusercontent.com/afo/data-x-plaksha/master/imgsource/dx_logo.png" align="left"></img><br><br><br><br>
#
#
# ## SOLUTIONS Breakout: Web scraping & web crawling
#
# **Author List**: Alexander Fred Ojala
#
# **Original Sources**: https://www.crummy.com/software/BeautifulSoup/bs4/doc/ & https://www.dataquest.io/blog/web-scraping-tutorial-python/
#
# **License**: Feel free to do whatever you want to with this code
#
# **Compatibility:** Python 2.x and 3.x

# %% [markdown]
# ---
# <a id='sec4'></a>
# # Breakout problem
#
#
# In this week's breakout you should extract live weather data in Berkeley from:
#
# [http://forecast.weather.gov/MapClick.php?lat=37.87158815800046&lon=-122.27274583799971](http://forecast.weather.gov/MapClick.php?lat=37.87158815800046&lon=-122.27274583799971)
#
# * Task scrape
#     * period / day (as Tonight, Friday, FridayNight etc.
#     * the temperature for the period (as Low, High)
#     * the long weather description (e.g. Partly cloudy, with a low around 49..)
#
# Store the scraped data strings in a Pandas DataFrame
#
#
#
# **Hint:** The weather information is found in a div tag with `id='seven-day-forecast'`

# %% [markdown]
# # Breakout solution

# %%
import requests
import bs4 as bs
import pandas as pd

source = requests.get('http://forecast.weather.gov/MapClick.php?lat=37.87158815800046&lon=-122.27274583799971').content
soup = bs.BeautifulSoup(source,features='lxml')

# %%
forecast = soup.find(id='seven-day-forecast')

# %%
print(forecast.prettify())
# Out:
# <div class="panel panel-default" id="seven-day-forecast">
#  <div class="panel-heading">
#   <b>
#    Extended Forecast for
#   </b>
#   <h2 class="panel-title">
#    Berkeley CA
#   </h2>
#  </div>
#  <div class="panel-body" id="seven-day-forecast-body">
#   <div id="seven-day-forecast-container">
#    <ul class="list-unstyled" id="seven-day-forecast-list">
#     <li class="forecast-tombstone">
#      <div class="tombstone-container">
#       <p class="period-name">
#        Tonight
#        <br/>
#        <br/>
#       </p>
#       <p>
#        <img alt="Tonight: Mostly clear, with a low around 46. North wind 6 to 8 mph. " class="forecast-icon" src="newimages/medium/nfew.png" title="Tonight: Mostly clear, with a low around 46. North wind 6 to 8 mph. "/>
#       </p>
#       <p class="short-desc">
#        Mostly Clear
#       </p>
#       <p class="temp temp-low">
#        Low: 46 °F
#       </p>
#      </div>
#     </li>
#     <li class="forecast-tombstone">
#      <div class="tombstone-container">
#       <p class="period-name">
#        Thanksgiving
#        <br/>
#        Day
#       </p>
#       <p>
#        <img alt="Thanksgiving Day: Sunny, with a high near 63. North northeast wind 10 to 14 mph. " class="forecast-icon" src="newimages/medium/few.png" title="Thanksgiving Day: Sunny, with a high near 63. North northeast wind 10 to 14 mph. "/>
#       </p>
#       <p class="short-desc">
#        Sunny
#       </p>
#       <p class="temp temp-high">
#        High: 63 °F
#       </p>
#      </div>
#     </li>
#     <li class="forecast-tombstone">
#      <div class="tombstone-container">
#       <p class="period-name">
#        Thursday
#        <br/>
#        Night
#       </p>
#       <p>
#        <img alt="Thursday Night: Mostly clear, with a low around 44. Northeast wind 3 to 7 mph. " class="forecast-icon" src="newimages/medium/nfew.png" title="Thursday Night: Mostly clear, with a low around 44. Northeast wind 3 to 7 mph. "/>
#       </p>
#       <p class="short-desc">
#        Mostly Clear
#       </p>
#       <p class="temp temp-low">
#        Low: 44 °F
#       </p>
#      </div>
#     </li>
#     <li class="forecast-tombstone">
#      <div class="tombstone-container">
#       <p class="period-name">
#        Friday
#        <br/>
#        <br/>
#       </p>
#       <p>
#        <img alt="Friday: Sunny, with a high near 61. Northeast wind around 7 mph. " class="forecast-icon" src="newimages/medium/few.png" title="Friday: Sunny, with a high near 61. Northeast wind around 7 mph. "/>
#       </p>
#       <p class="short-desc">
#        Sunny
#       </p>
#       <p class="temp temp-high">
#        High: 61 °F
#       </p>
#      </div>
#     </li>
#     <li class="forecast-tombstone">
#      <div class="tombstone-container">
#       <p class="period-name">
#        Friday
#        <br/>
#        Night
#       </p>
#       <p>
#        <img alt="Friday Night: Mostly clear, with a low around 42. Calm wind. " class="forecast-icon" src="newimages/medium/nfew.png" title="Friday Night: Mostly clear, with a low around 42. Calm wind. "/>
#       </p>
#       <p class="short-desc">
#        Mostly Clear
#       </p>
#       <p class="temp temp-low">
#        Low: 42 °F
#       </p>
#      </div>
#     </li>
#     <li class="forecast-tombstone">
#      <div class="tombstone-container">
#       <p class="period-name">
#        Saturday
#        <br/>
#        <br/>
#       </p>
#       <p>
#        <img alt="Saturday: Sunny, with a high near 61." class="forecast-icon" src="newimages/medium/few.png" title="Saturday: Sunny, with a high near 61."/>
#       </p>
#       <p class="short-desc">
#        Sunny
#       </p>
#       <p class="temp temp-high">
#        High: 61 °F
#       </p>
#      </div>
#     </li>
#     <li class="forecast-tombstone">
#      <div class="tombstone-container">
#       <p class="period-name">
#        Saturday
#        <br/>
#        Night
#       </p>
#       <p>
#        <img alt="Saturday Night: Mostly clear, with a low around 42." class="forecast-icon" src="newimages/medium/nfew.png" title="Saturday Night: Mostly clear, with a low around 42."/>
#       </p>
#       <p class="short-desc">
#        Mostly Clear
#       </p>
#       <p class="temp temp-low">
#        Low: 42 °F
#       </p>
#      </div>
#     </li>
#     <li class="forecast-tombstone">
#      <div class="tombstone-container">
#       <p class="period-name">
#        Sunday
#        <br/>
#        <br/>
#       </p>
#       <p>
#        <img alt="Sunday: Mostly sunny, with a high near 60." class="forecast-icon" src="newimages/medium/sct.png" title="Sunday: Mostly sunny, with a high near 60."/>
#       </p>
#       <p class="short-desc">
#        Mostly Sunny
#       </p>
#       <p class="temp temp-high">
#        High: 60 °F
#       </p>
#      </div>
#     </li>
#     <li class="forecast-tombstone">
#      <div class="tombstone-container">
#       <p class="period-name">
#        Sunday
#        <br/>
#        Night
#       </p>
#       <p>
#        <img alt="Sunday Night: Partly cloudy, with a low around 44." class="forecast-icon" src="newimages/medium/nsct.png" title="Sunday Night: Partly cloudy, with a low around 44."/>
#       </p>
#       <p class="short-desc">
#        Partly Cloudy
#       </p>
#       <p class="temp temp-low">
#        Low: 44 °F
#       </p>
#      </div>
#     </li>
#    </ul>
#   </div>
#   <script type="text/javascript">
#    // equalize forecast heights
# $(function () {
# 	var maxh = 0;
# 	$(".forecast-tombstone .short-desc").each(function () {
# 		var h = $(this).height();
# 		if (h > maxh) { maxh = h; }
# 	});
# 	$(".forecast-tombstone .short-desc").height(maxh);
# });
#   </script>
#  </div>
# </div>

# %%
day = [d.text for d in forecast.find_all(class_='period-name')]
temp = [temp.text for temp in forecast.find_all(class_='temp')]
desc = forecast.find_all('img')
short_desc = [f.text for f in forecast.find_all(class_="short-desc")]

# %%
print(day)
print()
print(temp)
print(short_desc)
# Out:
# ['Tonight', 'ThanksgivingDay', 'ThursdayNight', 'Friday', 'FridayNight', 'Saturday', 'SaturdayNight', 'Sunday', 'SundayNight']
#
# ['Low: 46 °F', 'High: 63 °F', 'Low: 44 °F', 'High: 61 °F', 'Low: 42 °F', 'High: 61 °F', 'Low: 42 °F', 'High: 60 °F', 'Low: 44 °F']
# ['Mostly Clear', 'Sunny', 'Mostly Clear', 'Sunny', 'Mostly Clear', 'Sunny', 'Mostly Clear', 'Mostly Sunny', 'Partly Cloudy']

# %%
# extract weather description
desc_list=list()
for txt in desc:
    print(txt.get('alt'))
    desc_list.append(txt.get('alt'))
# Out:
# Tonight: Mostly clear, with a low around 46. North wind 6 to 8 mph.
# Thanksgiving Day: Sunny, with a high near 63. North northeast wind 10 to 14 mph.
# Thursday Night: Mostly clear, with a low around 44. Northeast wind 3 to 7 mph.
# Friday: Sunny, with a high near 61. Northeast wind around 7 mph.
# Friday Night: Mostly clear, with a low around 42. Calm wind.
# Saturday: Sunny, with a high near 61.
# Saturday Night: Mostly clear, with a low around 42.
# Sunday: Mostly sunny, with a high near 60.
# Sunday Night: Partly cloudy, with a low around 44.

# %%
pd.set_option('display.max_colwidth', -1) # to print full results
df = pd.DataFrame({'day':day,'temp':temp, 'short_desc':short_desc,'desc':desc_list})
print('Berkeley 7 day weather forecast')
df
# Out:
# Berkeley 7 day weather forecast
# /Users/afo/.pyenv/versions/3.7.4/envs/data-x/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   """Entry point for launching an IPython kernel.
#                day         temp     short_desc  \
# 0  Tonight          Low: 46 °F   Mostly Clear
# 1  ThanksgivingDay  High: 63 °F  Sunny
# 2  ThursdayNight    Low: 44 °F   Mostly Clear
# 3  Friday           High: 61 °F  Sunny
# 4  FridayNight      Low: 42 °F   Mostly Clear
# 5  Saturday         High: 61 °F  Sunny
# 6  SaturdayNight    Low: 42 °F   Mostly Clear
# 7  Sunday           High: 60 °F  Mostly Sunny
# 8  SundayNight      Low: 44 °F   Partly Cloudy
#
#                                                                                 desc
# 0  Tonight: Mostly clear, with a low around 46. North wind 6 to 8 mph.
# 1  Thanksgiving Day: Sunny, with a high near 63. North northeast wind 10 to 14 mph.
# 2  Thursday Night: Mostly clear, with a low around 44. Northeast wind 3 to 7 mph.
# 3  Friday: Sunny, with a high near 61. Northeast wind around 7 mph.
# 4  Friday Night: Mostly clear, with a low around 42. Calm wind.
# 5  Saturday: Sunny, with a high near 61.
# 6  Saturday Night: Mostly clear, with a low around 42.
# 7  Sunday: Mostly sunny, with a high near 60.
# 8  Sunday Night: Partly cloudy, with a low around 44.

# %%
pd.options.display.max_colwidth=50 #change back to default max col_width
