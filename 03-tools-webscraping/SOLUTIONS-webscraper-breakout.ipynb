# %% [markdown]
# <img src="http://i67.tinypic.com/2jcbwcw.png" align="left"></img><br><br><br><br>
#
#
# ## SOLUTIONS Breakout: Web scraping & web crawling
#
# **Author List**: Alexander Fred Ojala
#
# **Original Sources**: https://www.crummy.com/software/BeautifulSoup/bs4/doc/ & https://www.dataquest.io/blog/web-scraping-tutorial-python/
#
# **License**: Feel free to do whatever you want to with this code
#
# **Compatibility:** Python 2.x and 3.x

# %% [markdown]
# ---
# <a id='sec4'></a>
# # Breakout problem
#
#
# In this week's breakout you should extract live weather data in Berkeley from:
#
# [http://forecast.weather.gov/MapClick.php?lat=37.87158815800046&lon=-122.27274583799971](http://forecast.weather.gov/MapClick.php?lat=37.87158815800046&lon=-122.27274583799971)
#
# * Task scrape
#     * period / day (as Tonight, Friday, FridayNight etc.
#     * the temperature for the period (as Low, High)
#     * the long weather description (e.g. Partly cloudy, with a low around 49..)
#
# Store the scraped data strings in a Pandas DataFrame
#
#
#
# **Hint:** The weather information is found in a div tag with `id='seven-day-forecast'`

# %% [markdown]
# # Breakout solution

# %%
import requests
import bs4 as bs
import pandas as pd

source = requests.get('http://forecast.weather.gov/MapClick.php?lat=37.87158815800046&lon=-122.27274583799971').content
soup = bs.BeautifulSoup(source,features='lxml')

# %%
forecast = soup.find(id='seven-day-forecast')

# %%
print(forecast.prettify())
# Out:
# <div class="panel panel-default" id="seven-day-forecast">
#  <div class="panel-heading">
#   <b>
#    Extended Forecast for
#   </b>
#   <h2 class="panel-title">
#    Berkeley CA
#   </h2>
#  </div>
#  <div class="panel-body" id="seven-day-forecast-body">
#   <div id="seven-day-forecast-container">
#    <ul class="list-unstyled" id="seven-day-forecast-list">
#     <li class="forecast-tombstone">
#      <div class="tombstone-container">
#       <p class="period-name">
#        Today
#        <br/>
#        <br/>
#       </p>
#       <p>
#        <img alt="Today: Sunny, with a high near 76. North wind around 14 mph, with gusts as high as 18 mph. " class="forecast-icon" src="newimages/medium/few.png" title="Today: Sunny, with a high near 76. North wind around 14 mph, with gusts as high as 18 mph. "/>
#       </p>
#       <p class="short-desc">
#        Sunny
#       </p>
#       <p class="temp temp-high">
#        High: 76 °F
#       </p>
#      </div>
#     </li>
#     <li class="forecast-tombstone">
#      <div class="tombstone-container">
#       <p class="period-name">
#        Tonight
#        <br/>
#        <br/>
#       </p>
#       <p>
#        <img alt="Tonight: Mostly clear, with a low around 48. East northeast wind 9 to 14 mph increasing to 15 to 20 mph after midnight. Winds could gust as high as 25 mph. " class="forecast-icon" src="newimages/medium/nfew.png" title="Tonight: Mostly clear, with a low around 48. East northeast wind 9 to 14 mph increasing to 15 to 20 mph after midnight. Winds could gust as high as 25 mph. "/>
#       </p>
#       <p class="short-desc">
#        Mostly Clear
#       </p>
#       <p class="temp temp-low">
#        Low: 48 °F
#       </p>
#      </div>
#     </li>
#     <li class="forecast-tombstone">
#      <div class="tombstone-container">
#       <p class="period-name">
#        Wednesday
#        <br/>
#        <br/>
#       </p>
#       <p>
#        <img alt="Wednesday: Sunny, with a high near 75. East northeast wind 16 to 21 mph decreasing to 10 to 15 mph in the afternoon. Winds could gust as high as 26 mph. " class="forecast-icon" src="newimages/medium/few.png" title="Wednesday: Sunny, with a high near 75. East northeast wind 16 to 21 mph decreasing to 10 to 15 mph in the afternoon. Winds could gust as high as 26 mph. "/>
#       </p>
#       <p class="short-desc">
#        Sunny
#       </p>
#       <p class="temp temp-high">
#        High: 75 °F
#       </p>
#      </div>
#     </li>
#     <li class="forecast-tombstone">
#      <div class="tombstone-container">
#       <p class="period-name">
#        Wednesday
#        <br/>
#        Night
#       </p>
#       <p>
#        <img alt="Wednesday Night: Clear, with a low around 50. East northeast wind 7 to 9 mph. " class="forecast-icon" src="newimages/medium/nskc.png" title="Wednesday Night: Clear, with a low around 50. East northeast wind 7 to 9 mph. "/>
#       </p>
#       <p class="short-desc">
#        Clear
#       </p>
#       <p class="temp temp-low">
#        Low: 50 °F
#       </p>
#      </div>
#     </li>
#     <li class="forecast-tombstone">
#      <div class="tombstone-container">
#       <p class="period-name">
#        Thursday
#        <br/>
#        <br/>
#       </p>
#       <p>
#        <img alt="Thursday: Sunny, with a high near 73. Calm wind becoming west around 6 mph in the morning. " class="forecast-icon" src="newimages/medium/skc.png" title="Thursday: Sunny, with a high near 73. Calm wind becoming west around 6 mph in the morning. "/>
#       </p>
#       <p class="short-desc">
#        Sunny
#       </p>
#       <p class="temp temp-high">
#        High: 73 °F
#       </p>
#      </div>
#     </li>
#     <li class="forecast-tombstone">
#      <div class="tombstone-container">
#       <p class="period-name">
#        Thursday
#        <br/>
#        Night
#       </p>
#       <p>
#        <img alt="Thursday Night: Mostly clear, with a low around 49." class="forecast-icon" src="newimages/medium/nfew.png" title="Thursday Night: Mostly clear, with a low around 49."/>
#       </p>
#       <p class="short-desc">
#        Mostly Clear
#       </p>
#       <p class="temp temp-low">
#        Low: 49 °F
#       </p>
#      </div>
#     </li>
#     <li class="forecast-tombstone">
#      <div class="tombstone-container">
#       <p class="period-name">
#        Friday
#        <br/>
#        <br/>
#       </p>
#       <p>
#        <img alt="Friday: Sunny, with a high near 71." class="forecast-icon" src="newimages/medium/few.png" title="Friday: Sunny, with a high near 71."/>
#       </p>
#       <p class="short-desc">
#        Sunny
#       </p>
#       <p class="temp temp-high">
#        High: 71 °F
#       </p>
#      </div>
#     </li>
#     <li class="forecast-tombstone">
#      <div class="tombstone-container">
#       <p class="period-name">
#        Friday
#        <br/>
#        Night
#       </p>
#       <p>
#        <img alt="Friday Night: Mostly clear, with a low around 48." class="forecast-icon" src="newimages/medium/nfew.png" title="Friday Night: Mostly clear, with a low around 48."/>
#       </p>
#       <p class="short-desc">
#        Mostly Clear
#       </p>
#       <p class="temp temp-low">
#        Low: 48 °F
#       </p>
#      </div>
#     </li>
#     <li class="forecast-tombstone">
#      <div class="tombstone-container">
#       <p class="period-name">
#        Saturday
#        <br/>
#        <br/>
#       </p>
#       <p>
#        <img alt="Saturday: Sunny, with a high near 70." class="forecast-icon" src="newimages/medium/few.png" title="Saturday: Sunny, with a high near 70."/>
#       </p>
#       <p class="short-desc">
#        Sunny
#       </p>
#       <p class="temp temp-high">
#        High: 70 °F
#       </p>
#      </div>
#     </li>
#    </ul>
#   </div>
#   <script type="text/javascript">
#    // equalize forecast heights
# $(function () {
# 	var maxh = 0;
# 	$(".forecast-tombstone .short-desc").each(function () {
# 		var h = $(this).height();
# 		if (h > maxh) { maxh = h; }
# 	});
# 	$(".forecast-tombstone .short-desc").height(maxh);
# });
#   </script>
#  </div>
# </div>

# %%
day = [d.text for d in forecast.find_all(class_='period-name')]
temp = [temp.text for temp in forecast.find_all(class_='temp')]
desc = forecast.find_all('img')

# %%
print(day)
print()
print(temp)
# Out:
# ['Today', 'Tonight', 'Wednesday', 'WednesdayNight', 'Thursday', 'ThursdayNight', 'Friday', 'FridayNight', 'Saturday']
#
# ['High: 76 °F', 'Low: 48 °F', 'High: 75 °F', 'Low: 50 °F', 'High: 73 °F', 'Low: 49 °F', 'High: 71 °F', 'Low: 48 °F', 'High: 70 °F']

# %%
# extract weather description
desc_list=list()
for txt in desc:
    print(txt.get('alt'))
    desc_list.append(txt.get('alt'))
# Out:
# Today: Sunny, with a high near 76. North wind around 14 mph, with gusts as high as 18 mph.
# Tonight: Mostly clear, with a low around 48. East northeast wind 9 to 14 mph increasing to 15 to 20 mph after midnight. Winds could gust as high as 25 mph.
# Wednesday: Sunny, with a high near 75. East northeast wind 16 to 21 mph decreasing to 10 to 15 mph in the afternoon. Winds could gust as high as 26 mph.
# Wednesday Night: Clear, with a low around 50. East northeast wind 7 to 9 mph.
# Thursday: Sunny, with a high near 73. Calm wind becoming west around 6 mph in the morning.
# Thursday Night: Mostly clear, with a low around 49.
# Friday: Sunny, with a high near 71.
# Friday Night: Mostly clear, with a low around 48.
# Saturday: Sunny, with a high near 70.

# %%
pd.set_option('display.max_colwidth', -1) # to print full results
df = pd.DataFrame({'day':day,'temp':temp,'desc':desc_list})
print('Berkeley 7 day weather forecast')
df
# Out:
# Berkeley 7 day weather forecast
#               day  \
# 0  Today
# 1  Tonight
# 2  Wednesday
# 3  WednesdayNight
# 4  Thursday
# 5  ThursdayNight
# 6  Friday
# 7  FridayNight
# 8  Saturday
#
#                                                                                                                                                            desc  \
# 0  Today: Sunny, with a high near 76. North wind around 14 mph, with gusts as high as 18 mph.
# 1  Tonight: Mostly clear, with a low around 48. East northeast wind 9 to 14 mph increasing to 15 to 20 mph after midnight. Winds could gust as high as 25 mph.
# 2  Wednesday: Sunny, with a high near 75. East northeast wind 16 to 21 mph decreasing to 10 to 15 mph in the afternoon. Winds could gust as high as 26 mph.
# 3  Wednesday Night: Clear, with a low around 50. East northeast wind 7 to 9 mph.
# 4  Thursday: Sunny, with a high near 73. Calm wind becoming west around 6 mph in the morning.
# 5  Thursday Night: Mostly clear, with a low around 49.
# 6  Friday: Sunny, with a high near 71.
# 7  Friday Night: Mostly clear, with a low around 48.
# 8  Saturday: Sunny, with a high near 70.
#
#           temp
# 0  High: 76 °F
# 1  Low: 48 °F
# 2  High: 75 °F
# 3  Low: 50 °F
# 4  High: 73 °F
# 5  Low: 49 °F
# 6  High: 71 °F
# 7  Low: 48 °F
# 8  High: 70 °F

# %%
pd.options.display.max_colwidth=50 #change back to default max col_width
